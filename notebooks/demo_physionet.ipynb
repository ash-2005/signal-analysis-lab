# %% [markdown]
# # Signal Analysis Lab: PhysioNet ECG Demo
# This notebook applies the library to two-channel PhysioNet ECG data.

# %%
# Example on how to load data and run analysis
import numpy as np
import matplotlib.pyplot as plt
from src.decompose import decompose_pipeline

# Please load data locally if using this notebook interactively.
